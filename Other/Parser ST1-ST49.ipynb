# %%
from datetime import date, timedelta
import urllib.request
import pandas as pd

# %%
today = date.today() - timedelta(days=1)
today
# Out:
# datetime.date(2020, 10, 15)

# %%
d97 = today.strftime('FAC%m%d.html')
d97
# Out:
# 'FAC1015.html'

# %%
d1 = today.strftime("WELLS%m%d.TXT")
d11 = today.strftime("WELLS%m%d.txt")

url1 = 'https://www.aer.ca/data/well-lic/' + d1
urllib.request.urlretrieve(url1, 'ST1/'+d11)
# Out:
# ('ST1/WELLS0818.txt', <http.client.HTTPMessage at 0x7f042a2650d0>)

# %%
d49 = today.strftime("SPUD%m%d.txt")

url49 = 'http://www.aer.ca/data/wells/' + d49
urllib.request.urlretrieve(url49, 'ST49/'+d49)
# Out:
# ('ST49/SPUD0818.txt', <http.client.HTTPMessage at 0x7f042a259f10>)

# %%
#Run Notebooks
# %run ./Parser-ST1.ipynb
# %run ./Parser-ST49.ipynb
